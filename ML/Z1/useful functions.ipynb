# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#PCA = principal component analysis
np.sort
np.argsort
matrix.min(axis=1, keepdims = True)
matrix.mean
np.unique(return_counts/index/inverse)
.fct? or shift + tab in .fct()

# %%
n=10000
x=np.random.randn(n)
y=np.random.randn(n)
fig, ax = plt.subplots(1)
plt.scatter(x, y, marker='.') #more args for prettier plots
ax.set_aspect('equal')
plt.show()

# %%
#UMAP
import UMAP
features = np.random.randn(p, N)
features = features.T

reducer = umap.UMAP()
projection = reducer.fit_transform
'''examples
interlockes rings -> detatches rings
sphere -> flattened sphere'''
